# %%
#Data Processing
import pandas as pd

#Linear Algebra
import numpy as np

#Data Visualization
import seaborn as sns
from matplotlib import pyplot as plt
from matplotlib import style

#Algorithms
from sklearn import linear_model
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import Perceptron
from sklearn.linear_model import SGDClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC, LinearSVC
from sklearn.naive_bayes import GaussianNB

df = pd.read_csv("titanic.csv")

#Compares Male Suvrvivors and Female Survivors to to age
survived = 'Survived'
not_survived = 'Not Survived'
fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(10,4))
women = df[df['Sex'] == 'female']
men = df[df['Sex'] == 'male']
ax = sns.distplot(women[women['Survived'] == 1].Age.dropna(), bins=18, label = survived, ax = axes[0], kde = False)

ax = sns.distplot(women[women['Survived'] == 0].Age.dropna(), bins=40, label=not_survived, ax=axes[0], kde=False)

ax.legend()
ax.set_title('Female')

ax = sns.distplot(men[men['Survived'] == 1].Age.dropna(), bins=18, label = survived, ax = axes[1], kde = False)
ax = sns.distplot(men[men['Survived'] == 0].Age.dropna(), bins=40, label = not_survived, ax = axes[1], kde = False)

ax.legend()
_ = ax.set_title('Male')

# %%
survived = 'Survived'
not_survived = 'Not Survived'
child = 'Child'
adult = 'Adult'
fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(10,4))
child = df[df['Age'] <= 18]
adult = df[df['Age'] >= 19]
ax = sns.distplot(child[child['Survived'] == 1].Age.dropna(), bins=18, label = survived, ax = axes[0], kde = False)

ax = sns.distplot(child[child['Survived'] == 0].Age.dropna(), bins=40, label=not_survived, ax=axes[0], kde=False)

ax.legend()
ax.set_title('Child')

ax = sns.distplot(adult[adult['Survived'] == 1].Age.dropna(), bins=18, label = survived, ax = axes[1], kde = False)
ax = sns.distplot(adult[adult['Survived'] == 0].Age.dropna(), bins=40, label = not_survived, ax = axes[1], kde = False)

ax.legend()
_ = ax.set_title('Adult')

# %%
female_child = 'FemaleChild'
male_child = 'MaleChild'
survived = 'Survived'
not_survived = 'Not Survived'
fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(10,4))

women = df[df['Sex'] == 'female']
men = df[df['Sex'] == 'male']

female_child = df[df['Age'] <= 18] 
male_child = df[df['Age'] <= 18]

women = female_child
men = male_child

ax = sns.distplot(female_child[female_child['Survived'] == 1].Age.dropna(), bins=18, label = survived, ax = axes[0], kde = False)

ax = sns.distplot(female_child[female_child['Survived'] == 0].Age.dropna(), bins=40, label=not_survived, ax=axes[0], kde=False)

ax.legend()
ax.set_title('Female Children')

ax = sns.distplot(male_child[male_child['Survived'] == 1].Age.dropna(), bins=18, label = survived, ax = axes[1], kde = False)
ax = sns.distplot(male_child[male_child['Survived'] == 0].Age.dropna(), bins=40, label = not_survived, ax = axes[1], kde = False)

ax.legend()
_ = ax.set_title('Male Children')

# %%
rich = 'Rich'
poor = 'Poor'
survived = 'Survived'
not_survived = 'Not Survived'
fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(10,4))
rich = df[df['Fare'] >= 40]
poor = df[df['Fare'] <= 39.99]
ax = sns.distplot(rich[rich['Survived'] == 1].Age.dropna(), bins=18, label = survived, ax = axes[0], kde = False)

ax = sns.distplot(rich[rich['Survived'] == 0].Age.dropna(), bins=40, label=not_survived, ax=axes[0], kde=False)

ax.legend()
ax.set_title('Rich')

ax = sns.distplot(poor[poor['Survived'] == 1].Age.dropna(), bins=18, label = survived, ax = axes[1], kde = False)
ax = sns.distplot(poor[poor['Survived'] == 0].Age.dropna(), bins=40, label = not_survived, ax = axes[1], kde = False)

ax.legend()
_ = ax.set_title('Poor')

# %%
rich_woman = 'Rich Woman'
poor_woman = 'Poor Woman'
survived = 'Survived'
not_survived = 'Not Survived'
fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(10,4))
rich_woman = df[df['Fare'] >= 40]
poor_woman = df[df['Fare'] <= 39.99]
ax = sns.distplot(rich_woman[rich_woman['Survived'] == 1].Age.dropna(), bins=18, label = survived, ax = axes[0], kde = False)

ax = sns.distplot(rich_woman[rich_woman['Survived'] == 0].Age.dropna(), bins=40, label=not_survived, ax=axes[0], kde=False)

ax.legend()
ax.set_title('Rich Women')

ax = sns.distplot(poor_woman[poor_woman['Survived'] == 1].Age.dropna(), bins=18, label = survived, ax = axes[1], kde = False)
ax = sns.distplot(poor_woman[poor_woman['Survived'] == 0].Age.dropna(), bins=40, label = not_survived, ax = axes[1], kde = False)

ax.legend()
_ = ax.set_title('Poor Women')

# %%
rich_man = 'Rich Man'
poor_man = 'Poor Man'
survived = 'Survived'
not_survived = 'Not Survived'
fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(10,4))
rich_man = df[df['Fare'] >= 40]
poor_man = df[df['Fare'] <= 39.99]
ax = sns.distplot(rich_man[rich_man['Survived'] == 1].Age.dropna(), bins=18, label = survived, ax = axes[0], kde = False)

ax = sns.distplot(rich_man[rich_man['Survived'] == 0].Age.dropna(), bins=40, label=not_survived, ax=axes[0], kde=False)

ax.legend()
ax.set_title('Rich Men')

ax = sns.distplot(poor_man[poor_man['Survived'] == 1].Age.dropna(), bins=18, label = survived, ax = axes[1], kde = False)
ax = sns.distplot(poor_man[poor_man['Survived'] == 0].Age.dropna(), bins=40, label = not_survived, ax = axes[1], kde = False)

ax.legend()
_ = ax.set_title('Poor Men')
